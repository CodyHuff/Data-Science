# %% [markdown]
# <a href="https://colab.research.google.com/github/CodyHuff/Data-Science/blob/main/Cody_huff_3_Load_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
url = 'https://raw.githubusercontent.com/CodyHuff/Probability_Statistics/main/dataset/train/beach/Beach/%231.jpg'

# %%
im = imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off');
